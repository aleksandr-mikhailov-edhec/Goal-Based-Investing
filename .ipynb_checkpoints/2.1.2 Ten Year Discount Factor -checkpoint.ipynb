# %%
import pandas as pd
import numpy as np
import matplotlib. pyplot as plt
from scipy.stats import norm

# %load_ext autoreload
# %autoreload 2

# %%
# Define the file path
file_path = "data/case_study_data.xlsx"

# Load the Excel file
xls = pd.ExcelFile(file_path)

# Read the "ZC yields" sheet (case insensitive)
zc_yields_df = pd.read_excel(xls, sheet_name="ZC yields",index_col=0)

# %%
zc_yields_df
# Out:
#                           Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# Zero-coupon yield curves
# Maturity (years)            0.000000    1.000000    2.000000    3.000000
# Effective date                   NaN         NaN         NaN         NaN
# 2014-10-31 00:00:00         0.001525    0.001525    0.005385    0.009872
# 2014-11-03 00:00:00         0.001631    0.001631    0.005533    0.010066
# 2014-11-04 00:00:00         0.001439    0.001439    0.005512    0.010062
# ...                              ...         ...         ...         ...
# 2024-10-28 00:00:00         0.042701    0.042701    0.040979    0.040501
# 2024-10-29 00:00:00         0.042583    0.042583    0.040861    0.040406
# 2024-10-30 00:00:00         0.042760    0.042760    0.041321    0.040869
# 2024-10-31 00:00:00         0.042704    0.042704    0.041250    0.040893
# 2024-11-01 00:00:00         0.042869    0.042869    0.041762    0.041474
#
# ...

# %%
# Drop the first row (column names) and the second row (which contains NaN)
zc_yields_df = zc_yields_df.iloc[2:]
zc_yields_df
# Out:
#                           Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# Zero-coupon yield curves
# 2014-10-31                  0.001525    0.001525    0.005385    0.009872
# 2014-11-03                  0.001631    0.001631    0.005533    0.010066
# 2014-11-04                  0.001439    0.001439    0.005512    0.010062
# 2014-11-05                  0.001556    0.001556    0.005611    0.010135
# 2014-11-06                  0.001682    0.001682    0.005814    0.010413
# ...                              ...         ...         ...         ...
# 2024-10-28                  0.042701    0.042701    0.040979    0.040501
# 2024-10-29                  0.042583    0.042583    0.040861    0.040406
# 2024-10-30                  0.042760    0.042760    0.041321    0.040869
# 2024-10-31                  0.042704    0.042704    0.041250    0.040893
# 2024-11-01                  0.042869    0.042869    0.041762    0.041474
#
# ...

# %%
# Out:
#      Zero-coupon yield curves  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0         2014-10-31 00:00:00    0.001525    0.001525    0.005385    0.009872
# 1         2014-11-03 00:00:00    0.001631    0.001631    0.005533    0.010066
# 2         2014-11-04 00:00:00    0.001439    0.001439    0.005512    0.010062
# 3         2014-11-05 00:00:00    0.001556    0.001556    0.005611    0.010135
# 4         2014-11-06 00:00:00    0.001682    0.001682    0.005814    0.010413
# ...                       ...         ...         ...         ...         ...
# 2513      2024-10-28 00:00:00    0.042701    0.042701    0.040979    0.040501
# 2514      2024-10-29 00:00:00    0.042583    0.042583    0.040861    0.040406
# 2515      2024-10-30 00:00:00    0.042760    0.042760    0.041321    0.040869
# 2516      2024-10-31 00:00:00    0.042704    0.042704    0.041250    0.040893
# 2517      2024-11-01 00:00:00    0.042869    0.042869    0.041762    0.041474
#
# ...

# %%
# Rename remaining columns to match the maturity values (0-30 years)
maturity_columns = list(range(0, 31))
zc_yields_df.columns = maturity_columns[:len(zc_yields_df.columns)]
zc_yields_df.index.name = "Date"

# %%
zc_yields_df
# Out:
#                   0         1         2         3         4         5   \
# Date
# 2014-10-31  0.001525  0.001525  0.005385  0.009872  0.013707  0.016728
# 2014-11-03  0.001631  0.001631  0.005533  0.010066  0.013901  0.016893
# 2014-11-04  0.001439  0.001439  0.005512  0.010062  0.013873  0.016836
# 2014-11-05  0.001556  0.001556  0.005611  0.010135  0.013922  0.016873
# 2014-11-06  0.001682  0.001682  0.005814  0.010413  0.014241  0.017211
# ...              ...       ...       ...       ...       ...       ...
# 2024-10-28  0.042701  0.042701  0.040979  0.040501  0.040558  0.040855
# 2024-10-29  0.042583  0.042583  0.040861  0.040406  0.040491  0.040813
# 2024-10-30  0.042760  0.042760  0.041321  0.040869  0.040888  0.041134
# 2024-10-31  0.042704  0.042704  0.041250  0.040893  0.040968  0.041225
# 2024-11-01  0.042869  0.042869  0.041762  0.041474  0.041587  0.041896
#
#                   6         7         8         9   ...        21        22  \
# ...

# %%
import pandas as pd
import numpy as np
from scipy.interpolate import CubicSpline

# zc_yields_df: rows = dates, columns = maturities (in years)
dates = zc_yields_df.index
maturities = zc_yields_df.columns.astype(float)  

initial_date = dates[0]
discount_factors = []

for current_date in dates:
    # 1. Day-count fraction from initial_date to current_date
    delta_days = (current_date - initial_date).days  # day-count
    delta_t = delta_days / 365.0  # if using Actual/365

    # 2. Effective maturity for the original 10-year instrument
    T_eff = 10 - delta_t
    if T_eff <= 0:
        # Once T_eff <= 0, the bond is effectively matured
        discount_factors.append(1.0)
        continue

    # 3. Fit cubic spline for this date
    yields_today = zc_yields_df.loc[current_date, :].values  # yields for each maturity
    spline = CubicSpline(maturities, yields_today)

    # 4. Interpolate yield for T_eff
    yield_T = spline(T_eff)  # annualized zero-coupon yield

    # 5. Compute discount factor (continuous compounding)
    DF = np.exp(-yield_T * T_eff)
    discount_factors.append(DF)

# Convert discount_factors into a Series for convenience
df_result = pd.Series(discount_factors, index=dates, name="DiscountFactor_10yr")

# %%
df_result
# Out:
# Date
# 2014-10-31    0.782063
# 2014-11-03    0.782077
# 2014-11-04    0.783352
# 2014-11-05    0.782667
# 2014-11-06    0.779901
#                 ...
# 2024-10-28    1.000000
# 2024-10-29    1.000000
# 2024-10-30    1.000000
# 2024-10-31    1.000000
# 2024-11-01    1.000000
# Name: DiscountFactor_10yr, Length: 2518, dtype: float64

# %%
import matplotlib.pyplot as plt

# Plot the discount factor series
plt.figure(figsize=(10, 5))
df_result.plot()
plt.title("Discount Factor for 10-Year Maturity Over Time")
plt.xlabel("Date")
plt.ylabel("Discount Factor")
plt.grid(True)
plt.show()
