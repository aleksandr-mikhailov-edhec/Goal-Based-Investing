# %% [markdown]
# In this notebook I check consistency of my code and results from Risk Institute of EDHEC.
#
#
# Inputs:
# - parameters for stochastic simulations
#
# <img src="pictures/Input parameters.png" width="400">
#
#
# - inputs for period t=0 are taken as long term values of SR, stock returns, volatility and risk free rate
# - apart from reported correlations I use correlation of interest rate with other parameters = 0; correlation of stock volatility and shar[e rati0 = +76.7%
# - 20 years investment horizon
# - 100 initial wealth
# - 0.1 invested in risky asset and 0.9 invested in zero-coupon bond

# %% [markdown]
# ## Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

import market_stochastic_simulation as mss
import retirement_client as pensioner

# %% [markdown]
# # 1. Market Simulation Code

# %% [markdown]
# $
# \begin{cases}
# r_{t+dt} = r_t + \kappa_r (\bar{lt_r} - r_t) dt + \sigma_r \sqrt{dt} Z_t^r\\
# SR_{t+dt} = SR_t + \kappa_sr (\bar{lt_sr} - SR_t) dt + \sigma_SR \sqrt{dt} Z_t^SR\\
# V_{t+dt} = V_t + \kappa_v (lt_V - V_t) dt + \sigma_V \sqrt{V_t} \sqrt{dt} Z_t^V\\
# S_{t+dt} = S_t \times \exp \left( \left( r + \bar{\lambda_0} \sigma_t - \frac{1}{2} \sigma_t^2 \right) dt + \sigma_t \sqrt{dt} Z_t^S \right) \\
# \end{cases}
# $

# %%
# Parameters
S0 = 1.0              # asset price
T = 20                  # time in years
N = 252*T              # number of time steps in simulation
M = 1000                # number of simulated paths
seed = 124              # simulation seed

simulated_market = mss.MarketSimulator(T,N,M,seed, S0)
simulated_market.plot_market_simulation()

# %% [markdown]
# ## Initialize client
#
# Find cash flows the client needs

# %%
client = pensioner.RetirementClient("Lionel",
                           accumulation_years=20,
                           accumulation_cash_flow=0,
                           decumulation_years=1,
                           decumulation_cash_flow=100,
                           periodicity = 12)

client.plot_cash_flows()

# %% [markdown]
# Now we know cash flows that the client needs. Hence, we can simulate perfect zero coupon bond for him

# %%
simulated_market.calculate_perfect_retirement_bond(client)
# Out:
# Simulating scenarios:   0%|                            | 0/1000 [00:00<?, ?it/s]
# Simulating scenarios:   2%|▎                  | 16/1000 [00:02<02:43,  6.01it/s]
# Simulating scenarios:   2%|▍                  | 24/1000 [00:04<03:03,  5.32it/s]
# Simulating scenarios:   3%|▌                  | 32/1000 [00:06<03:07,  5.16it/s]
# Simulating scenarios:   4%|▊                  | 40/1000 [00:07<03:12,  5.00it/s]
# Simulating scenarios:   5%|▉                  | 48/1000 [00:09<03:15,  4.88it/s]
# Simulating scenarios:   6%|█                  | 56/1000 [00:11<03:14,  4.85it/s]
# Simulating scenarios:   6%|█▏                 | 64/1000 [00:12<03:13,  4.85it/s]
# Simulating scenarios:   7%|█▎                 | 72/1000 [00:14<03:07,  4.94it/s]
# Simulating scenarios:   8%|█▌                 | 80/1000 [00:15<03:06,  4.94it/s]
# Simulating scenarios:   9%|█▋                 | 88/1000 [00:17<03:06,  4.88it/s]
# Simulating scenarios:  10%|█▊                 | 96/1000 [00:19<03:05,  4.87it/s]
# Simulating scenarios:  10%|█▊                | 104/1000 [00:20<02:57,  5.04it/s]
# Simulating scenarios:  11%|██                | 112/1000 [00:22<02:51,  5.17it/s]
# Simulating scenarios:  12%|██▏               | 120/1000 [00:23<02:46,  5.28it/s]
# Simulating scenarios:  13%|██▎               | 128/1000 [00:25<02:44,  5.31it/s]
# Simulating scenarios:  14%|██▍               | 136/1000 [00:26<02:43,  5.29it/s]
# Simulating scenarios:  14%|██▌               | 144/1000 [00:28<02:39,  5.36it/s]
# Simulating scenarios:  15%|██▋               | 152/1000 [00:29<02:47,  5.06it/s]
# Simulating scenarios:  16%|██▉               | 160/1000 [00:31<02:50,  4.92it/s]
# Simulating scenarios:  17%|███               | 168/1000 [00:33<02:49,  4.90it/s]
# Simulating scenarios:  18%|███▏              | 176/1000 [00:34<02:43,  5.03it/s]
# Simulating scenarios:  18%|███▎              | 184/1000 [00:36<02:37,  5.17it/s]
# Simulating scenarios:  19%|███▍              | 192/1000 [00:38<02:46,  4.86it/s]
# Simulating scenarios:  20%|███▌              | 200/1000 [00:39<02:47,  4.79it/s]
# Simulating scenarios:  21%|███▋              | 208/1000 [00:41<02:53,  4.56it/s]
# Simulating scenarios:  22%|███▉              | 216/1000 [00:43<02:54,  4.48it/s]
# Simulating scenarios:  22%|████              | 224/1000 [00:45<02:58,  4.35it/s]
# Simulating scenarios:  23%|████▏             | 232/1000 [00:47<03:00,  4.26it/s]
# Simulating scenarios:  24%|████▎             | 240/1000 [00:49<02:47,  4.53it/s]
# Simulating scenarios:  25%|████▍             | 248/1000 [00:50<02:40,  4.69it/s]
# Simulating scenarios:  26%|████▌             | 256/1000 [00:52<02:38,  4.71it/s]
# Simulating scenarios:  26%|████▊             | 264/1000 [00:54<02:49,  4.35it/s]
# Simulating scenarios:  27%|████▉             | 272/1000 [00:56<02:53,  4.20it/s]
# Simulating scenarios:  28%|█████             | 280/1000 [00:58<02:44,  4.38it/s]
# Simulating scenarios:  29%|█████▏            | 288/1000 [00:59<02:40,  4.45it/s]
# Simulating scenarios:  30%|█████▎            | 296/1000 [01:01<02:36,  4.51it/s]
# Simulating scenarios:  30%|█████▍            | 304/1000 [01:03<02:29,  4.66it/s]
# Simulating scenarios:  31%|█████▌            | 312/1000 [01:05<02:31,  4.54it/s]
# Simulating scenarios:  32%|█████▊            | 320/1000 [01:07<02:36,  4.36it/s]
# Simulating scenarios:  33%|█████▉            | 328/1000 [01:08<02:26,  4.59it/s]
# Simulating scenarios:  34%|██████            | 336/1000 [01:10<02:20,  4.72it/s]
# Simulating scenarios:  34%|██████▏           | 344/1000 [01:11<02:15,  4.84it/s]
# Simulating scenarios:  35%|██████▎           | 352/1000 [01:13<02:11,  4.94it/s]
# Simulating scenarios:  36%|██████▍           | 360/1000 [01:14<02:11,  4.87it/s]
# Simulating scenarios:  37%|██████▌           | 368/1000 [01:16<02:08,  4.92it/s]
# Simulating scenarios:  38%|██████▊           | 376/1000 [01:18<02:09,  4.83it/s]
# Simulating scenarios:  38%|██████▉           | 384/1000 [01:20<02:10,  4.70it/s]
# Simulating scenarios:  39%|███████           | 392/1000 [01:21<02:05,  4.84it/s]
# Simulating scenarios:  40%|███████▏          | 400/1000 [01:23<02:03,  4.84it/s]
# Simulating scenarios:  41%|███████▎          | 408/1000 [01:24<02:00,  4.92it/s]
# Simulating scenarios:  42%|███████▍          | 416/1000 [01:26<01:58,  4.93it/s]
# Simulating scenarios:  42%|███████▋          | 424/1000 [01:28<01:59,  4.82it/s]
# Simulating scenarios:  43%|███████▊          | 432/1000 [01:29<01:58,  4.81it/s]
# Simulating scenarios:  44%|███████▉          | 440/1000 [01:31<01:52,  4.96it/s]
# Simulating scenarios:  45%|████████          | 448/1000 [01:32<01:50,  4.98it/s]
# Simulating scenarios:  46%|████████▏         | 456/1000 [01:34<01:49,  4.97it/s]
# Simulating scenarios:  46%|████████▎         | 464/1000 [01:36<01:48,  4.93it/s]
# Simulating scenarios:  47%|████████▍         | 472/1000 [01:37<01:45,  5.02it/s]
# Simulating scenarios:  48%|████████▋         | 480/1000 [01:39<01:42,  5.07it/s]
# Simulating scenarios:  49%|████████▊         | 488/1000 [01:40<01:39,  5.13it/s]
# Simulating scenarios:  50%|████████▉         | 496/1000 [01:42<01:37,  5.17it/s]
# Simulating scenarios:  50%|█████████         | 504/1000 [01:44<01:45,  4.71it/s]
# Simulating scenarios:  51%|█████████▏        | 512/1000 [01:45<01:41,  4.83it/s]
# Simulating scenarios:  52%|█████████▎        | 520/1000 [01:47<01:38,  4.86it/s]
# Simulating scenarios:  53%|█████████▌        | 528/1000 [01:49<01:37,  4.85it/s]
# Simulating scenarios:  54%|█████████▋        | 536/1000 [01:50<01:34,  4.91it/s]
# Simulating scenarios:  54%|█████████▊        | 544/1000 [01:52<01:32,  4.90it/s]
# Simulating scenarios:  55%|█████████▉        | 552/1000 [01:53<01:29,  4.99it/s]
# Simulating scenarios:  56%|██████████        | 560/1000 [01:55<01:26,  5.09it/s]
# Simulating scenarios:  57%|██████████▏       | 568/1000 [01:56<01:23,  5.15it/s]
# Simulating scenarios:  58%|██████████▎       | 576/1000 [01:58<01:21,  5.19it/s]
# Simulating scenarios:  58%|██████████▌       | 584/1000 [02:00<01:20,  5.18it/s]
# Simulating scenarios:  59%|██████████▋       | 592/1000 [02:01<01:22,  4.95it/s]
# Simulating scenarios:  60%|██████████▊       | 600/1000 [02:03<01:19,  5.02it/s]
# Simulating scenarios:  61%|██████████▉       | 608/1000 [02:04<01:16,  5.10it/s]
# Simulating scenarios:  62%|███████████       | 616/1000 [02:06<01:16,  5.01it/s]
# Simulating scenarios:  62%|███████████▏      | 624/1000 [02:08<01:14,  5.06it/s]
# Simulating scenarios:  63%|███████████▍      | 632/1000 [02:09<01:15,  4.87it/s]
# Simulating scenarios:  64%|███████████▌      | 640/1000 [02:11<01:13,  4.90it/s]
# Simulating scenarios:  65%|███████████▋      | 648/1000 [02:13<01:10,  4.96it/s]
# Simulating scenarios:  66%|███████████▊      | 656/1000 [02:14<01:08,  5.04it/s]
# Simulating scenarios:  66%|███████████▉      | 664/1000 [02:16<01:04,  5.18it/s]
# Simulating scenarios:  67%|████████████      | 672/1000 [02:17<01:03,  5.13it/s]
# Simulating scenarios:  68%|████████████▏     | 680/1000 [02:19<01:08,  4.70it/s]
# Simulating scenarios:  69%|████████████▍     | 688/1000 [02:21<01:05,  4.78it/s]
# Simulating scenarios:  70%|████████████▌     | 696/1000 [02:22<01:03,  4.81it/s]
# Simulating scenarios:  70%|████████████▋     | 704/1000 [02:25<01:07,  4.37it/s]
# Simulating scenarios:  71%|████████████▊     | 712/1000 [02:26<01:04,  4.50it/s]
# Simulating scenarios:  72%|████████████▉     | 720/1000 [02:28<01:00,  4.60it/s]
# Simulating scenarios:  73%|█████████████     | 728/1000 [02:30<01:00,  4.49it/s]
# Simulating scenarios:  74%|█████████████▏    | 736/1000 [02:32<01:02,  4.21it/s]
# Simulating scenarios:  74%|█████████████▍    | 744/1000 [02:34<00:58,  4.35it/s]
# Simulating scenarios:  75%|█████████████▌    | 752/1000 [02:36<00:57,  4.29it/s]
# Simulating scenarios:  76%|█████████████▋    | 760/1000 [02:37<00:55,  4.30it/s]
# Simulating scenarios:  77%|█████████████▊    | 768/1000 [02:40<00:58,  3.99it/s]
# Simulating scenarios:  78%|█████████████▉    | 776/1000 [02:42<00:55,  4.04it/s]
# Simulating scenarios:  78%|██████████████    | 784/1000 [02:43<00:51,  4.20it/s]
# Simulating scenarios:  79%|██████████████▎   | 792/1000 [02:45<00:50,  4.15it/s]
# Simulating scenarios:  80%|██████████████▍   | 800/1000 [02:47<00:45,  4.39it/s]
# Simulating scenarios:  81%|██████████████▌   | 808/1000 [02:49<00:42,  4.56it/s]
# Simulating scenarios:  82%|██████████████▋   | 816/1000 [02:50<00:39,  4.72it/s]
# Simulating scenarios:  82%|██████████████▊   | 824/1000 [02:52<00:36,  4.81it/s]
# Simulating scenarios:  83%|██████████████▉   | 832/1000 [02:53<00:34,  4.91it/s]
# Simulating scenarios:  84%|███████████████   | 840/1000 [02:55<00:32,  4.97it/s]
# Simulating scenarios:  85%|███████████████▎  | 848/1000 [02:56<00:30,  4.96it/s]
# Simulating scenarios:  86%|███████████████▍  | 856/1000 [02:58<00:29,  4.96it/s]
# Simulating scenarios:  86%|███████████████▌  | 864/1000 [03:00<00:26,  5.11it/s]
# Simulating scenarios:  87%|███████████████▋  | 872/1000 [03:01<00:25,  5.11it/s]
# Simulating scenarios:  88%|███████████████▊  | 880/1000 [03:03<00:24,  4.94it/s]
# Simulating scenarios:  89%|███████████████▉  | 888/1000 [03:04<00:21,  5.12it/s]
# Simulating scenarios:  90%|████████████████▏ | 896/1000 [03:06<00:20,  5.10it/s]
# Simulating scenarios:  90%|████████████████▎ | 904/1000 [03:08<00:19,  5.00it/s]
# Simulating scenarios:  91%|████████████████▍ | 912/1000 [03:09<00:17,  4.94it/s]
# Simulating scenarios:  92%|████████████████▌ | 920/1000 [03:11<00:15,  5.03it/s]
# Simulating scenarios:  93%|████████████████▋ | 928/1000 [03:12<00:14,  5.00it/s]
# Simulating scenarios:  94%|████████████████▊ | 936/1000 [03:14<00:13,  4.91it/s]
# Simulating scenarios:  94%|████████████████▉ | 944/1000 [03:16<00:11,  4.95it/s]
# Simulating scenarios:  95%|█████████████████▏| 952/1000 [03:17<00:09,  4.95it/s]
# Simulating scenarios:  96%|█████████████████▎| 960/1000 [03:19<00:08,  4.93it/s]
# Simulating scenarios:  97%|█████████████████▍| 968/1000 [03:20<00:06,  4.96it/s]
# Simulating scenarios:  98%|█████████████████▌| 976/1000 [03:22<00:04,  4.89it/s]
# Simulating scenarios:  98%|█████████████████▋| 984/1000 [03:24<00:03,  4.75it/s]
# Simulating scenarios:  99%|█████████████████▊| 992/1000 [03:26<00:01,  4.73it/s]
# Simulating scenarios: 100%|█████████████████| 1000/1000 [03:27<00:00,  4.81it/s]
# /Users/aleksandrmikhailov/Desktop/GitHub_EDHEC/Retirement solution/Goal-Based-Investing/market_stochastic_simulation.py:295: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   retirement_bond_p.loc[:, simulation_number] = result[i]

# %% [markdown]
# Plot the market and the zero coupon bond.

# %%
simulated_market.plot_market_simulation()

# %% [markdown]
# ## Find fixed mix fund performance (rebalanced daily)

# %%
risky_asset_returns  = simulated_market.S_p.pct_change().iloc[1:,:]
safe_asset_returns  = simulated_market.retirement_bond_p.pct_change().iloc[1:,:]

# %%
FM_fund_performance_10 = risky_asset_returns*0.1+safe_asset_returns*0.9
FM_fund_performance_20 = risky_asset_returns*0.2+safe_asset_returns*0.8
FM_fund_performance_30 = risky_asset_returns*0.3+safe_asset_returns*0.7

initial_wealth = 100

portfolio_wealth_10 = (FM_fund_performance_10+1).cumprod()*100
portfolio_wealth_20 = (FM_fund_performance_20+1).cumprod()*100
portfolio_wealth_30 = (FM_fund_performance_30+1).cumprod()*100

# %%
# Plot histogram with enhancements
plt.figure(figsize=(8, 5))  # Adjust figure size

plt.hist(portfolio_wealth_30.iloc[-1, :], bins=30, color="darkblue", edgecolor="black", alpha=0.75, label = 'Aggressive', density=True)
plt.hist(portfolio_wealth_20.iloc[-1, :], bins=20, color="darkred", edgecolor="black", alpha=0.75, label = 'Moderate', density=True)
plt.hist(portfolio_wealth_10.iloc[-1, :], bins=10, color="darkgreen", edgecolor="black", alpha=0.75, label = 'Defensive', density=True)

# Titles and Labels
plt.title("Fixed-Mix Strategues", fontsize=14, fontweight='bold')
plt.xlabel("Terminal Wealth", fontsize=12)
plt.ylabel("Frequency", fontsize=12)

# Grid for readability
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show the improved plot
plt.show()

# %%
portfolio_wealth_10.iloc[-1,:].mean().round(2)
# Out:
# 212.45

# %% [markdown]
# Resulting wealth is significantly different from the simulation results obtained in "Dynamic Liability-Driven Investing Strategies: The Emergence of a New Investment Paradigm for Pension Funds? — February 2014":
#
# <img src="pictures/FM_strategy.png" width="400">
